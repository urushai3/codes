# %%
# !pip install klib

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("/content/data cleaning - Sheet3.csv")

# %%
import klib

# %%
klib.cat_plot(df)
# Out:
# GridSpec(6, 7)

# %%
# klib.corr_mat(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-645320a2f03d> in <cell line: 1>()
# ----> 1 klib.corr_mat(df)
#
# /usr/local/lib/python3.10/dist-packages/klib/describe.py in corr_mat(data, split, threshold, target, method, colored)
#     245     data = pd.DataFrame(data)
#     246
# --> 247     _validate_input_num_data(data, "data")
#     248
#     249     if isinstance(target, (str, list, pd.Series, np.ndarray)):
#
# /usr/local/lib/python3.10/dist-packages/klib/utils.py in _validate_input_num_data(value, desc)
#     281     if value.select_dtypes(include=["number"]).empty:
#     282         msg = f"Input value for '{desc}' should contain at least one numerical column."
# --> 283         raise TypeError(msg)
#
# TypeError: Input value for 'data' should contain at least one numerical column.

# %%
# klib.corr_plot(df)

# %%
# klib.dist_plot(df)
# Out:
# No columns with numeric data were detected.

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)
